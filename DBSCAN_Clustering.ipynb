# %%
from sklearn.cluster import DBSCAN 
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

# %%
X,y=make_blobs(n_samples=1500,centers=[[4,4],[3,-2],[1,1],[1,2]],cluster_std=0.9)
print(X)
# Out:
# [[3.94041315 4.4246247 ]
#  [3.70766792 2.83262578]
#  [1.77491364 2.36892684]
#  ...
#  [1.95068635 1.35345258]
#  [3.11538482 4.11698809]
#  [3.02497624 3.23373974]]

# %%
epsilon=0.3
minimumSamples=7
db=DBSCAN(eps=epsilon,min_samples=minimumSamples).fit(X)
labels=db.labels_
labels
# Out:
# array([0, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
#-1 indicates noise or outliers
n_clusters=len(set(labels))-(-1 if -1 in labels else 0)
n_clusters
# Out:
# 6

# %%
unique_labels=set(labels)
unique_labels
# Out:
# {-1, 0, 1, 2, 3}

# %%
fig=plt.figure(figsize=(6,4))
ax=fig.add_subplot(1,1,1)
colors=plt.cm.Spectral(np.linspace(0,1,len(set(labels))))
for k,col in zip(unique_labels,colors):
    if k==-1:
        col="k"
    my_members=(k==labels)
    print(my_members)
    xy=X[my_members]
    ax.scatter(xy[:,0],xy[:,1],c=col, marker=u'o', alpha=0.5)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# [ True  True False ... False  True  True]
# [False False  True ...  True False False]
# [False False False ... False False False]
# [False False False ... False False False]
# [False False False ... False False False]

# %%
a=[1,2,3,4]
a=np.asanyarray(a)
for i in range(4):
    my=(i==a)
    print(my)
# Out:
# [False False False False]
# [ True False False False]
# [False  True False False]
# [False False  True False]
